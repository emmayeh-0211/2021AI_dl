# %% [markdown]
# <a href="https://colab.research.google.com/github/emmayeh-0211/2021AI_dl/blob/main/01_Conv_Parameters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
import numpy as np

# %%
# 28 * 28 
# 28 * 28 * 1
# Batch_size, 28, 28, 1

# %%
# 1 filter
model = keras.models.Sequential([
    keras.layers.Input((4, 4, 3)),
    keras.layers.Conv2D(filters=1, kernel_size=3)                                
])
model.summary()
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 2, 2, 1)           28
# ...
# Total params: 28
# Trainable params: 28
# Non-trainable params: 0
# _________________________________________________________________

# %%
# output shape: (None, 2, 2, 1) = (Batch size, feature maps size, feature maps size, output dims)

# %%
img = np.random.normal(0, 1, (32, 28, 28, 3))
img.shape
# Out:
# (32, 28, 28, 3)

# %%
output = model(img) # tensorflow的形式
# 類似丟進 model.predict(img)的結果，只是這個的是 numpy.array的形式

# %%
output.shape # batch_size, img_size, img_size, channels
# Out:
# TensorShape([32, 26, 26, 1])

# %%
# 2 filters
model = keras.models.Sequential([
    keras.layers.Input((4,4,3)),
    keras.layers.Conv2D(filters=2, kernel_size=3)
])
model.summary()
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 2, 2, 2)           56
# ...
# Total params: 56
# Trainable params: 56
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 8 channels input, 2 filters
model = keras.models.Sequential([
    keras.layers.Input((4, 4, 8)),
    keras.layers.Conv2D(filters=2, kernel_size=3)
])
model.summary()
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_2 (Conv2D)            (None, 2, 2, 2)           146
# ...
# Total params: 146
# Trainable params: 146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Q: Will input larger image size change model paramters (with **flatten** layer)? 3. 變多
#
# Q: Will input larger image size change model paramters (with **Global average pooling** layer)? 1.不變
#
# 1: 不變
# 2: 變少
# 3: 變多

# %%
# 使用 flatten，total參數數量 264,650
# 使用 Global average pooling，total參數數量 17,354
# 現大多使用 Global average pooling 來減少參數量

# %%
# 100x100: 
model = keras.models.Sequential([
    keras.layers.Input((100, 100 ,3)),
    keras.layers.Conv2D(16, 3),
    keras.layers.Conv2D(16, 3),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(32, 3),
    keras.layers.Conv2D(32, 3),
    keras.layers.MaxPooling2D(2),
    # keras.layers.Flatten(), 
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dense(16),
    keras.layers.Dense(10),
])
model.summary()
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_35 (Conv2D)           (None, 98, 98, 16)        448
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 96, 96, 16)        2320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 48, 48, 16)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 46, 46, 32)        4640
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 44, 44, 32)        9248
# _________________________________________________________________
# ...

# %%
model = keras.models.Sequential([
    keras.layers.Input((2000, 2000 ,3)),
    keras.layers.Conv2D(16, 3),
    keras.layers.Conv2D(16, 3),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(32, 3),
    keras.layers.Conv2D(32, 3),
    keras.layers.MaxPooling2D(2),
    # keras.layers.Flatten(), 
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dense(16),
    keras.layers.Dense(10),
])
model.summary()
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7 (Conv2D)            (None, 1998, 1998, 16)    448
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 1996, 1996, 16)    2320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 998, 998, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 996, 996, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 994, 994, 32)      9248
# _________________________________________________________________
# ...

# %% [markdown]
# # Dynamic Input Size

# %%
model = keras.applications.EfficientNetB0(include_top=False, weights='imagenet',
                                          input_shape=(None, None, 3))
model.summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_18 (InputLayer)           [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# rescaling_4 (Rescaling)         (None, 64, 64, 3)    0           input_18[0][0]
# __________________________________________________________________________________________________
# normalization_4 (Normalization) (None, 64, 64, 3)    7           rescaling_4[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 65, 65, 3)    0           normalization_4[0][0]
# __________________________________________________________________________________________________
# ...

# %%
img_128 = np.random.normal(size=(1, 128, 128, 3))

output = model(img_128)
output.shape
# Out:
# TensorShape([1, 4, 4, 1280])

# %%
img_512 = np.random.normal(size=(1, 512, 512, 3))

output = model(img_512)
output.shape
# Out:
# TensorShape([1, 16, 16, 1280])

# %%
img_4 = np.random.normal(size=(1, 4, 4, 3))

output = model(img_4)
output.shape
# Out:
# TensorShape([1, 0, 0, 1280])

# %%
model = keras.applications.EfficientNetB0(include_top=True, weights='imagenet',
                                          input_shape=(224, 224, 3))
model.summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_16 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# rescaling_2 (Rescaling)         (None, 224, 224, 3)  0           input_16[0][0]
# __________________________________________________________________________________________________
# normalization_2 (Normalization) (None, 224, 224, 3)  7           rescaling_2[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 225, 225, 3)  0           normalization_2[0][0]
# __________________________________________________________________________________________________
# ...
