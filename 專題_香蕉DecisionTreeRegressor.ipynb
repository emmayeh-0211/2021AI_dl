# %% [markdown]
# <a href="https://colab.research.google.com/github/emmayeh-0211/2021AI_dl/blob/main/%E5%B0%88%E9%A1%8C_%E9%A6%99%E8%95%89DecisionTreeRegressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 掛載google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# index：日期
# input data：批發市場交易量、每日天氣、颱風警報
# output answer：批發市場每日交易價格

# %%
import pandas as pd
from IPython.display import display
# 資料來自個地方
w_file_path = '/content/drive/MyDrive/Ai團專_農時_共享資料夾/Dataset_資料集/氣候資料/各縣市氣候資料_0701/dataset.csv'
p_file_path = '/content/drive/MyDrive/Ai團專_農時_共享資料夾/Dataset_資料集/市場批發交易歷史資料/Banana.csv'
weather_df = pd.read_csv(w_file_path) # 氣候資料
weather_df.set_index(["date"], inplace=True)
price_df = pd.read_csv(p_file_path) # 香蕉的批發交易資料
filter = price_df.Market == '台北一' # 篩選出只有台北一的批發交易資料
price_df = price_df[filter]
price_df.set_index(["Date"], inplace=True)
display(weather_df.tail())
display(price_df.tail())
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (130,132,305,307) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            city_KLU  StnPres_KLU  ...  CloudAmount_TTT  WarnMark
# date                              ...
# 2021-06-14      基隆市        997.3  ...              4.5         0
# 2021-06-15      基隆市        994.7  ...              5.2         0
# 2021-06-16      基隆市        995.4  ...              4.4         0
# 2021-06-17      基隆市        996.9  ...              2.5         0
# 2021-06-18      基隆市        995.5  ...              2.4         0
#
# [5 rows x 666 columns]
#            Market  Product  Up_price  ...  Week_day  Year  Rest_day
# Date                                  ...
# 2021-06-15    台北一  A1 香蕉         NaN  ...         2  2021         1
# 2021-06-16    台北一  A1 香蕉         NaN  ...         3  2021         1
# 2021-06-17    台北一  A1 香蕉        32.5  ...         4  2021         0
# 2021-06-18    台北一  A1 香蕉        30.9  ...         5  2021         0
# 2021-06-19    台北一  A1 香蕉        33.4  ...         6  2021         0
#
# [5 rows x 11 columns]

# %%
# 天氣欄位太多，因此只保留 氣溫、最高溫、最低溫、風速、最大風速、雨量 這6個因素
# 縣市只挑選香蕉主要產地：高雄、屏東、南投 3個縣市
factors = ['Temperature', 'T_Max', 'T_Min', 'WS_', 'WSGust', 'Precp_']
citys = ['KHH', 'IUH', 'NTO']
keep = ['WarnMark']
for c in citys:
  for w in weather_df:
    if c in w:
      for f in factors:
        if f in w:
          keep.append(w)
weather_df = weather_df.loc[:, keep]
weather_df.tail()
# Out:
#             WarnMark  Temperature_KHH  WS_KHH  ...  WS_NTO  WSGust_NTO  Precp_NTO
# date                                           ...
# 2021-06-14         0             29.4     1.6  ...     1.6         7.4        0.4
# 2021-06-15         0             29.0     1.3  ...     1.7         7.7        0.7
# 2021-06-16         0             27.3     1.3  ...     1.8         7.6       12.2
# 2021-06-17         0             27.9     1.3  ...     1.8         7.7        4.5
# 2021-06-18         0             28.2     1.2  ...     1.8         7.5        1.4
#
# [5 rows x 13 columns]

# %%
# 將市場資料中的 價格及交易量空值補上0
values = {'Up_price':0, 'Mid_price':0, 'Low_price':0, 'Avg_price':0, 'Volume':0}
price_df = price_df.fillna(value=values)
price_df
# Out:
#            Market  Product  Up_price  ...  Week_day  Year  Rest_day
# Date                                  ...
# 2000-01-02    台北一  A1 香蕉        30.0  ...         7  2000         0
# 2000-01-03    台北一  A1 香蕉        26.0  ...         1  2000         0
# 2000-01-04    台北一  A1 香蕉        28.0  ...         2  2000         0
# 2000-01-05    台北一  A1 香蕉        28.0  ...         3  2000         0
# 2000-01-06    台北一  A1 香蕉        28.0  ...         4  2000         0
# ...           ...      ...       ...  ...       ...   ...       ...
# 2021-06-15    台北一  A1 香蕉         0.0  ...         2  2021         1
# 2021-06-16    台北一  A1 香蕉         0.0  ...         3  2021         1
# 2021-06-17    台北一  A1 香蕉        32.5  ...         4  2021         0
# 2021-06-18    台北一  A1 香蕉        30.9  ...         5  2021         0
# 2021-06-19    台北一  A1 香蕉        33.4  ...         6  2021         0
#
# [7840 rows x 11 columns]

# %%
# 合併 天氣因素表格&批發市場價格表格
new_df = pd.merge(weather_df, price_df, how='outer', left_index=True, right_index=True)
new_df = new_df[1: -1] # 2020.01.01 市場交易沒資料，跟最後一筆沒有天氣資料，所以用slice方式拿掉
display(new_df.head())
display(new_df.tail())
# Out:
#             WarnMark  Temperature_KHH  WS_KHH  ...  Week_day    Year  Rest_day
# 2000-01-02       0.0             21.0     1.7  ...       7.0  2000.0       0.0
# 2000-01-03       0.0             20.6     1.8  ...       1.0  2000.0       0.0
# 2000-01-04       0.0             20.8     1.9  ...       2.0  2000.0       0.0
# 2000-01-05       0.0             22.4     1.6  ...       3.0  2000.0       0.0
# 2000-01-06       0.0             21.9     1.2  ...       4.0  2000.0       0.0
#
# [5 rows x 24 columns]
#             WarnMark  Temperature_KHH  WS_KHH  ...  Week_day    Year  Rest_day
# 2021-06-14       0.0             29.4     1.6  ...       1.0  2021.0       0.0
# 2021-06-15       0.0             29.0     1.3  ...       2.0  2021.0       1.0
# 2021-06-16       0.0             27.3     1.3  ...       3.0  2021.0       1.0
# 2021-06-17       0.0             27.9     1.3  ...       4.0  2021.0       0.0
# 2021-06-18       0.0             28.2     1.2  ...       5.0  2021.0       0.0
#
# [5 rows x 24 columns]

# %%
# 另外因為只有針對單一市場跟作物，因此不需要 Market 跟 Product 兩個欄位了，使用drop方式移除
# 另外應該也不能放上中下價，也先移除
new_df = new_df.drop(columns=['Market', 'Product', 'Up_price', 'Mid_price', 'Low_price'])
display(new_df.head())
display(new_df.tail())
# Out:
#             WarnMark  Temperature_KHH  WS_KHH  ...  Week_day    Year  Rest_day
# 2000-01-02       0.0             21.0     1.7  ...       7.0  2000.0       0.0
# 2000-01-03       0.0             20.6     1.8  ...       1.0  2000.0       0.0
# 2000-01-04       0.0             20.8     1.9  ...       2.0  2000.0       0.0
# 2000-01-05       0.0             22.4     1.6  ...       3.0  2000.0       0.0
# 2000-01-06       0.0             21.9     1.2  ...       4.0  2000.0       0.0
#
# [5 rows x 19 columns]
#             WarnMark  Temperature_KHH  WS_KHH  ...  Week_day    Year  Rest_day
# 2021-06-14       0.0             29.4     1.6  ...       1.0  2021.0       0.0
# 2021-06-15       0.0             29.0     1.3  ...       2.0  2021.0       1.0
# 2021-06-16       0.0             27.3     1.3  ...       3.0  2021.0       1.0
# 2021-06-17       0.0             27.9     1.3  ...       4.0  2021.0       0.0
# 2021-06-18       0.0             28.2     1.2  ...       5.0  2021.0       0.0
#
# [5 rows x 19 columns]

# %%
# sklearn前：pandas.DataFrame
# sklearn後：np.array
import numpy as np
from sklearn.model_selection import train_test_split
x, y = np.array(new_df.drop(['Avg_price'], axis=1)), np.array(new_df['Avg_price'])
# 90% x, 10% x, 90% y, 10% y）
x_train, x_test, y_train, y_test = train_test_split(x,
                                                    y,
                                                    test_size=0.1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (7055, 18)
# (784, 18)
# (7055,)
# (784,)

# %%
# 使用決策樹這個演算法訓練模型
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(max_depth=5) # 創造模型
                                          # 可以透過設定模型深度，來預防過擬合的情形產生
reg.fit(x_train, y_train) # 餵資料給模型
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=5,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
# 把模型結果畫出來
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
feature_names = ['WarnMark', 'Temperature_KHH', 'WS_KHH', 'WSGust_KHH', 'Precp_KHH', 'Temperature_IUH', 'WS_IUH', 'WSGust_IUH', 'Precp_IUH', 'Temperature_NTO', 'WS_NTO', 'WSGust_NTO', 'Precp_NTO', 'Volume', 'Month', 'Week_day', 'Year', 'Rest_day']
print(feature_names)
plt.figure(figsize=(20, 20))
plot_tree(reg, 
          feature_names=feature_names,
          filled=True,
          max_depth=5)

# mse = 84.195 samples = 455 value = 22.483' 各自代表的意思
# mse 均方差 跟平均的平均距離
# samples 分類的數量 
# values 為 samples的平均
# Out:
# ['WarnMark', 'Temperature_KHH', 'WS_KHH', 'WSGust_KHH', 'Precp_KHH', 'Temperature_IUH', 'WS_IUH', 'WSGust_IUH', 'Precp_IUH', 'Temperature_NTO', 'WS_NTO', 'WSGust_NTO', 'Precp_NTO', 'Volume', 'Month', 'Week_day', 'Year', 'Rest_day']
# [Text(523.125, 996.6, 'Volume <= 2326.5\nmse = 246.663\nsamples = 7055\nvalue = 21.328'),
#  Text(488.25, 815.4000000000001, 'mse = 0.0\nsamples = 1202\nvalue = 0.0'),
#  Text(558.0, 815.4000000000001, 'Year <= 2007.5\nmse = 184.712\nsamples = 5853\nvalue = 25.709'),
#  Text(279.0, 634.2, 'Year <= 2003.5\nmse = 55.219\nsamples = 2205\nvalue = 17.598'),
#  Text(139.5, 453.0, 'Year <= 2001.5\nmse = 18.197\nsamples = 1099\nvalue = 13.72'),
#  Text(69.75, 271.79999999999995, 'Temperature_NTO <= 12.45\nmse = 17.365\nsamples = 549\nvalue = 16.229'),
#  Text(34.875, 90.59999999999991, 'mse = 10.675\nsamples = 258\nvalue = 18.724'),
#  Text(104.625, 90.59999999999991, 'mse = 12.881\nsamples = 291\nvalue = 14.016'),
#  Text(209.25, 271.79999999999995, 'Temperature_KHH <= 26.65\nmse = 6.479\nsamples = 550\nvalue = 11.217'),
#  Text(174.375, 90.59999999999991, 'mse = 9.033\nsamples = 272\nvalue = 12.384'),
#  Text(244.125, 90.59999999999991, 'mse = 1.341\nsamples = 278\nvalue = 10.074'),
#  Text(418.5, 453.0, 'Volume <= 14116.5\nmse = 62.212\nsamples = 1106\nvalue = 21.452'),
#  Text(348.75, 271.79999999999995, 'Year <= 2004.5\nmse = 62.772\nsamples = 280\nvalue = 28.595'),
#  Text(313.875, 90.59999999999991, 'mse = 28.011\nsamples = 77\nvalue = 20.626'),
#  Text(383.625, 90.59999999999991, 'mse = 42.735\nsamples = 203\nvalue = 31.617'),
#  Text(488.25, 271.79999999999995, 'Temperature_IUH <= 25.15\nmse = 38.865\nsamples = 826\nvalue = 19.031'),
#  Text(453.375, 90.59999999999991, 'mse = 37.444\nsamples = 370\nvalue = 22.806'),
#  Text(523.125, 90.59999999999991, 'mse = 19.07\nsamples = 456\nvalue = 15.967'),
#  Text(837.0, 634.2, 'Volume <= 17698.0\nmse = 199.196\nsamples = 3648\nvalue = 30.611'),
#  Text(697.5, 453.0, 'Temperature_KHH <= 26.45\nmse = 239.335\nsamples = 1365\nvalue = 37.62'),
#  Text(627.75, 271.79999999999995, 'Year <= 2013.5\nmse = 255.662\nsamples = 857\nvalue = 42.029'),
#  Text(592.875, 90.59999999999991, 'mse = 49.381\nsamples = 441\nvalue = 35.844'),
#  Text(662.625, 90.59999999999991, 'mse = 390.801\nsamples = 416\nvalue = 48.585'),
#  Text(767.25, 271.79999999999995, 'Temperature_KHH <= 28.75\nmse = 123.685\nsamples = 508\nvalue = 30.183'),
#  Text(732.375, 90.59999999999991, 'mse = 131.933\nsamples = 316\nvalue = 33.162'),
#  Text(802.125, 90.59999999999991, 'mse = 71.457\nsamples = 192\nvalue = 25.279'),
#  Text(976.5, 453.0, 'Temperature_KHH <= 27.45\nmse = 128.256\nsamples = 2283\nvalue = 26.42'),
#  Text(906.75, 271.79999999999995, 'WSGust_IUH <= 8.85\nmse = 127.88\nsamples = 1390\nvalue = 29.433'),
#  Text(871.875, 90.59999999999991, 'mse = 141.999\nsamples = 781\nvalue = 32.317'),
#  Text(941.625, 90.59999999999991, 'mse = 85.439\nsamples = 609\nvalue = 25.736'),
#  Text(1046.25, 271.79999999999995, 'WS_KHH <= 1.15\nmse = 92.702\nsamples = 893\nvalue = 21.729'),
#  Text(1011.375, 90.59999999999991, 'mse = 24.898\nsamples = 177\nvalue = 16.088'),
#  Text(1081.125, 90.59999999999991, 'mse = 99.651\nsamples = 716\nvalue = 23.123')]

# %%
from sklearn.metrics import r2_score
pre = reg.predict(x_test)
r2_score(y_test, pre)
# Out:
# 0.6774223706030249
