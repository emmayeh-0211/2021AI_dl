# %% [markdown]
# <a href="https://colab.research.google.com/github/emmayeh-0211/2021AI_dl/blob/main/vessel_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
from glob import glob
from tqdm.auto import tqdm
import imgaug.augmenters as iaa
import imgaug as ia
from tensorflow.keras import *
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split
import pandas as pd

# %% [markdown]
# #### Download data

# %%
# download dataset from https://drive.google.com/file/d/1JILW10sr40CRTLiuA1mf__5GBtMDF9xc/view?usp=sharing
# !gdown --id 1JILW10sr40CRTLiuA1mf__5GBtMDF9xc --output vessel_seg.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JILW10sr40CRTLiuA1mf__5GBtMDF9xc
# To: /content/vessel_seg.zip
# 29.2MB [00:00, 70.6MB/s]

# %%
# unzip file
# !unzip -q vessel_seg.zip

# %% [markdown]
# #### Data Analysis

# %%
# read img and mask
img_paths = glob('all/train/*.tif')
img_path = np.random.choice(img_paths, size=1)[0]
mask_path = img_path.replace('_training.tif', '_manual1.gif')

print('img path: ', img_path)
print('mask path:',  mask_path)

img = cv2.imread(img_path)[:, :, ::-1]
mask = Image.open(mask_path)
mask = np.array(mask)
# Out:
# img path:  all/train/34_training.tif
# mask path: all/train/34_manual1.gif

# %%
# show image
plt.figure(figsize=(20, 5))
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(mask, cmap='gray_r')
plt.show()

# %%
img.shape, mask.shape
# Out:
# ((584, 565, 3), (584, 565))

# %% [markdown]
# #### Data processing

# %%
IMG_SIZE = 512
BS = 4

# %%
class DataGenerator(utils.Sequence):
    def __init__(self, img_paths, batch_size, img_size, shuffle=True, mode='train', aug=False):
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.img_size = img_size
        self.mode = mode
        self.img_paths = img_paths
        self.mask_paths = [p.replace('_training.tif', '_manual1.gif') for p in self.img_paths]
        self.aug = aug
        self.indexes = np.arange(len(self.mask_paths))
        self.seq = iaa.Sequential([
            iaa.Fliplr(0.5), # 50% horizontal flip
            iaa.Flipud(0.5),
            iaa.Affine(
                rotate=(90, -90), # random rotate -45 ~ +45 degree
                shear=(-3,3), # random shear -16 ~ +16 degree
                scale={"x": (0.8, 1.2), "y": (0.8, 1.2)} # scale x, y: 80%~120%
            ),
        ])
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.mask_paths) / self.batch_size)) # batches per epoch

    def __getitem__(self, index):
        # Generate indexes of the batch
        idxs = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        # Find list of IDs
        batch_img_paths = [self.img_paths[i] for i in idxs]
        batch_mask_paths = [self.mask_paths[i] for i in idxs]

        # Generate data
        X, y = self.__data_generation(batch_img_paths, batch_mask_paths)
        if self.mode != 'test':
            return X, y
        else:
            return X

    def on_epoch_end(self):
        # Updates indexes after each epoch
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, img_paths, mask_paths):
        # Generates data containing batch_size samples
        x = np.empty((len(img_paths), self.img_size, self.img_size, 3), dtype=np.float32)
        y = np.empty((len(img_paths), self.img_size, self.img_size, 1), dtype=np.float32)

        for i, (img_path, mask_path) in enumerate(zip(img_paths, mask_paths)):
            img = cv2.imread(img_path)[:, :,::-1]
            img = self.preprocess(img)
            x[i] = img
            if self.mode != 'test':
                mask = np.array(Image.open(mask_path))
                mask = self.preprocess(mask)
                y[i] = np.expand_dims(mask, axis=-1)
        if self.aug:
            x, y = self.seq(images=x, heatmaps=y)
        return x, y

    def preprocess(self, img):
        data = cv2.resize(img, (self.img_size, self.img_size))
        data = data / 255. # normalize to 0~1
        return data

# %%
all_paths = glob('all/train/*.tif')
test_paths = sorted(glob('all/test/*.tif'))
train_paths, val_paths = train_test_split(all_paths, test_size=0.2)

train_gen = DataGenerator(train_paths, BS, IMG_SIZE, shuffle=True, mode='train', aug=True)
val_gen = DataGenerator(val_paths, BS, IMG_SIZE, shuffle=False, mode='val')
test_gen = DataGenerator(test_paths, BS, IMG_SIZE, shuffle=False, mode='test')

# %%
# Check output

batch_x, batch_y = train_gen[0]

batch_i = np.random.choice(len(batch_x))
plt.figure(figsize=(20, 5))
plt.subplot(1,2,1)
plt.imshow(batch_x[batch_i], cmap='gray_r')
plt.subplot(1,2,2)
plt.imshow(batch_y[batch_i, :, :, 0], cmap='gray_r')
plt.show()

# %% [markdown]
# #### Build model

# %%
def conv_bn(x, filters):
    x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x

input_layer = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = conv_bn(input_layer, 8)
c1 = conv_bn(x, 8)
x = layers.MaxPool2D(strides=(2,2))(c1)
x = conv_bn(x, 16)
c2 = conv_bn(x, 16)
x = layers.MaxPool2D(strides=(2,2))(c2)
x = conv_bn(x, 32)
c3 = conv_bn(x, 32)
x = layers.MaxPool2D(strides=(2,2))(c3)
x = conv_bn(x, 64)
c4 = conv_bn(x, 64)

x = layers.concatenate([layers.UpSampling2D(size=(2,2))(c4), c3], axis=-1)
x = conv_bn(x, 32)
x = conv_bn(x, 32)
x = layers.concatenate([layers.UpSampling2D(size=(2,2))(x), c2], axis=-1)
x = conv_bn(x, 64)
x = conv_bn(x, 64)
x = layers.concatenate([layers.UpSampling2D(size=(2,2))(x), c1], axis=-1)
x = conv_bn(x, 128)
x = conv_bn(x, 128)

output_layer = layers.Conv2D(filters=1, kernel_size=(1,1), activation='sigmoid')(x)
                                                         
model = models.Model(input_layer, output_layer)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 512, 512, 8)  224         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 512, 512, 8)  32          conv2d_30[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 512, 512, 8)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 512, 512, 8)  584         re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 512, 512, 8)  32          conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 512, 512, 8)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 256, 256, 8)  0           re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 256, 256, 16) 1168        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 256, 256, 16) 64          conv2d_32[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 256, 256, 16) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 256, 256, 16) 2320        re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 256, 256, 16) 64          conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 256, 256, 16) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 128, 128, 16) 0           re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 128, 128, 32) 4640        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 128, 128, 32) 128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 128, 128, 32) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 128, 128, 32) 9248        re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 128, 128, 32) 128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 128, 128, 32) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 32)   0           re_lu_33[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 64)   18496       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 64, 64, 64)   256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 64, 64, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 64)   36928       re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 64, 64, 64)   256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 64, 64, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 64) 0           re_lu_35[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 96) 0           up_sampling2d_6[0][0]
#                                                                  re_lu_33[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 128, 128, 32) 27680       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 128, 128, 32) 128         conv2d_38[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, 128, 128, 32) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 128, 128, 32) 9248        re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 128, 128, 32) 128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 128, 128, 32) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 32) 0           re_lu_37[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 48) 0           up_sampling2d_7[0][0]
#                                                                  re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 256, 256, 64) 27712       concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 256, 256, 64) 256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 256, 256, 64) 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 256, 256, 64) 36928       re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 256, 256, 64) 256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 256, 256, 64) 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 512, 512, 64) 0           re_lu_39[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 512, 512, 72) 0           up_sampling2d_8[0][0]
#                                                                  re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 512, 512, 128 83072       concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 512, 512, 128 512         conv2d_42[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 512, 512, 128 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 512, 512, 128 147584      re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 512, 512, 128 512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, 512, 512, 128 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 512, 512, 1)  129         re_lu_41[0][0]
# ==================================================================================================
# Total params: 408,713
# Trainable params: 407,337
# Non-trainable params: 1,376
# __________________________________________________________________________________________________

# %%
utils.plot_model(model, show_shapes=True)

# %% [markdown]
# #### Training

# %% [markdown]
# 骰子係數（Dice coefficient），是一種集合相似度度量函數，通常用於計算兩個樣本的相似度

# %%
# Customize Dice coefficient
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true) # 把正確答案攤平
    y_pred_f = K.flatten(y_pred)  # 把predict答案也攤平
    intersection = K.sum(y_true_f * y_pred_f) #再看他們的交集
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon()) # 1e-6, 1e-7

# %%
model.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=[dice_coef])

# %%
weight_saver = callbacks.ModelCheckpoint('seg.h5', monitor='val_loss', save_best_only=True)
earlystop = callbacks.EarlyStopping(monitor='val_loss', patience=100)

# %%
logs = model.fit(train_gen,
                 validation_data = val_gen,
                 epochs=1000,
                 callbacks = [weight_saver, earlystop])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 41s 608ms/step - loss: 0.6768 - dice_coef: 0.1649 - val_loss: 0.6772 - val_dice_coef: 0.1557
# Epoch 2/1000
# 4/4 [==============================] - 2s 482ms/step - loss: 0.3546 - dice_coef: 0.1676 - val_loss: 0.6474 - val_dice_coef: 0.1539
# Epoch 3/1000
# 4/4 [==============================] - 2s 479ms/step - loss: 0.2735 - dice_coef: 0.1735 - val_loss: 0.6098 - val_dice_coef: 0.1517
# Epoch 4/1000
# 4/4 [==============================] - 2s 480ms/step - loss: 0.2438 - dice_coef: 0.1858 - val_loss: 0.5628 - val_dice_coef: 0.1470
# Epoch 5/1000
# 4/4 [==============================] - 2s 480ms/step - loss: 0.2283 - dice_coef: 0.2216 - val_loss: 0.5359 - val_dice_coef: 0.1449
# Epoch 6/1000
# 4/4 [==============================] - 2s 482ms/step - loss: 0.2254 - dice_coef: 0.2328 - val_loss: 0.6035 - val_dice_coef: 0.1529
# Epoch 7/1000
# 4/4 [==============================] - 2s 482ms/step - loss: 0.2111 - dice_coef: 0.2691 - val_loss: 0.5787 - val_dice_coef: 0.1543
# Epoch 8/1000
# 4/4 [==============================] - 2s 485ms/step - loss: 0.2001 - dice_coef: 0.3289 - val_loss: 0.5685 - val_dice_coef: 0.1584
# Epoch 9/1000
# 4/4 [==============================] - 2s 485ms/step - loss: 0.1906 - dice_coef: 0.3551 - val_loss: 0.5181 - val_dice_coef: 0.1556
# Epoch 10/1000
# 4/4 [==============================] - 2s 486ms/step - loss: 0.1855 - dice_coef: 0.3450 - val_loss: 0.4514 - val_dice_coef: 0.1497
# Epoch 11/1000
# 4/4 [==============================] - 2s 483ms/step - loss: 0.1821 - dice_coef: 0.3849 - val_loss: 0.4101 - val_dice_coef: 0.1453
# Epoch 12/1000
# 4/4 [==============================] - 2s 486ms/step - loss: 0.1695 - dice_coef: 0.4285 - val_loss: 0.3835 - val_dice_coef: 0.1419
# Epoch 13/1000
# 4/4 [==============================] - 2s 487ms/step - loss: 0.1666 - dice_coef: 0.4249 - val_loss: 0.3569 - val_dice_coef: 0.1338
# Epoch 14/1000
# 4/4 [==============================] - 2s 486ms/step - loss: 0.1716 - dice_coef: 0.4361 - val_loss: 0.3508 - val_dice_coef: 0.1159
# Epoch 15/1000
# 4/4 [==============================] - 2s 487ms/step - loss: 0.1581 - dice_coef: 0.4280 - val_loss: 0.3519 - val_dice_coef: 0.1097
# Epoch 16/1000
# 4/4 [==============================] - 2s 487ms/step - loss: 0.1872 - dice_coef: 0.4452 - val_loss: 0.3567 - val_dice_coef: 0.1075
# Epoch 17/1000
# 4/4 [==============================] - 2s 487ms/step - loss: 0.1630 - dice_coef: 0.4474 - val_loss: 0.3467 - val_dice_coef: 0.0936
# Epoch 18/1000
# 4/4 [==============================] - 2s 493ms/step - loss: 0.1598 - dice_coef: 0.4660 - val_loss: 0.3433 - val_dice_coef: 0.1092
# Epoch 19/1000
# 4/4 [==============================] - 2s 489ms/step - loss: 0.1516 - dice_coef: 0.4886 - val_loss: 0.3436 - val_dice_coef: 0.1176
# Epoch 20/1000
# 4/4 [==============================] - 2s 492ms/step - loss: 0.1466 - dice_coef: 0.4988 - val_loss: 0.3434 - val_dice_coef: 0.1230
# Epoch 21/1000
# 4/4 [==============================] - 2s 486ms/step - loss: 0.1407 - dice_coef: 0.4938 - val_loss: 0.3264 - val_dice_coef: 0.1060
# Epoch 22/1000
# 4/4 [==============================] - 2s 489ms/step - loss: 0.1532 - dice_coef: 0.4992 - val_loss: 0.3271 - val_dice_coef: 0.1017
# Epoch 23/1000
# 4/4 [==============================] - 2s 490ms/step - loss: 0.1449 - dice_coef: 0.5104 - val_loss: 0.3254 - val_dice_coef: 0.0967
# Epoch 24/1000
# 4/4 [==============================] - 2s 490ms/step - loss: 0.1315 - dice_coef: 0.5251 - val_loss: 0.3236 - val_dice_coef: 0.0934
# Epoch 25/1000
# 4/4 [==============================] - 2s 493ms/step - loss: 0.1575 - dice_coef: 0.5133 - val_loss: 0.3212 - val_dice_coef: 0.0901
# Epoch 26/1000
# 4/4 [==============================] - 2s 491ms/step - loss: 0.1532 - dice_coef: 0.5109 - val_loss: 0.3154 - val_dice_coef: 0.1046
# Epoch 27/1000
# 4/4 [==============================] - 2s 492ms/step - loss: 0.1423 - dice_coef: 0.5307 - val_loss: 0.3257 - val_dice_coef: 0.0832
# Epoch 28/1000
# 4/4 [==============================] - 2s 493ms/step - loss: 0.1321 - dice_coef: 0.5340 - val_loss: 0.3130 - val_dice_coef: 0.0980
# Epoch 29/1000
# 4/4 [==============================] - 2s 490ms/step - loss: 0.1365 - dice_coef: 0.5195 - val_loss: 0.3266 - val_dice_coef: 0.0792
# Epoch 30/1000
# 4/4 [==============================] - 2s 493ms/step - loss: 0.1398 - dice_coef: 0.5437 - val_loss: 0.3390 - val_dice_coef: 0.0665
# Epoch 31/1000
# 4/4 [==============================] - 2s 496ms/step - loss: 0.1512 - dice_coef: 0.5413 - val_loss: 0.3504 - val_dice_coef: 0.0576
# Epoch 32/1000
# 4/4 [==============================] - 2s 499ms/step - loss: 0.1274 - dice_coef: 0.5665 - val_loss: 0.3535 - val_dice_coef: 0.0557
# Epoch 33/1000
# 4/4 [==============================] - 2s 495ms/step - loss: 0.1305 - dice_coef: 0.5565 - val_loss: 0.3554 - val_dice_coef: 0.0526
# Epoch 34/1000
# 4/4 [==============================] - 2s 497ms/step - loss: 0.1262 - dice_coef: 0.5629 - val_loss: 0.3466 - val_dice_coef: 0.0589
# Epoch 35/1000
# 4/4 [==============================] - 2s 496ms/step - loss: 0.1269 - dice_coef: 0.5374 - val_loss: 0.3595 - val_dice_coef: 0.0507
# Epoch 36/1000
# 4/4 [==============================] - 2s 498ms/step - loss: 0.1342 - dice_coef: 0.5542 - val_loss: 0.3564 - val_dice_coef: 0.0548
# Epoch 37/1000
# 4/4 [==============================] - 2s 497ms/step - loss: 0.1245 - dice_coef: 0.5650 - val_loss: 0.3799 - val_dice_coef: 0.0445
# Epoch 38/1000
# 4/4 [==============================] - 2s 494ms/step - loss: 0.1234 - dice_coef: 0.5751 - val_loss: 0.3777 - val_dice_coef: 0.0469
# Epoch 39/1000
# 4/4 [==============================] - 2s 498ms/step - loss: 0.1307 - dice_coef: 0.5539 - val_loss: 0.3368 - val_dice_coef: 0.0802
# Epoch 40/1000
# 4/4 [==============================] - 2s 499ms/step - loss: 0.1258 - dice_coef: 0.5652 - val_loss: 0.3266 - val_dice_coef: 0.0913
# Epoch 41/1000
# 4/4 [==============================] - 2s 499ms/step - loss: 0.1177 - dice_coef: 0.5783 - val_loss: 0.3540 - val_dice_coef: 0.0712
# Epoch 42/1000
# 4/4 [==============================] - 2s 500ms/step - loss: 0.1303 - dice_coef: 0.5668 - val_loss: 0.4160 - val_dice_coef: 0.0325
# Epoch 43/1000
# 4/4 [==============================] - 2s 503ms/step - loss: 0.1282 - dice_coef: 0.5859 - val_loss: 0.3680 - val_dice_coef: 0.0624
# Epoch 44/1000
# 4/4 [==============================] - 2s 503ms/step - loss: 0.1268 - dice_coef: 0.5777 - val_loss: 0.3757 - val_dice_coef: 0.0567
# Epoch 45/1000
# 4/4 [==============================] - 2s 502ms/step - loss: 0.1240 - dice_coef: 0.5798 - val_loss: 0.3968 - val_dice_coef: 0.0473
# Epoch 46/1000
# 4/4 [==============================] - 2s 501ms/step - loss: 0.1207 - dice_coef: 0.5848 - val_loss: 0.3922 - val_dice_coef: 0.0500
# Epoch 47/1000
# 4/4 [==============================] - 2s 501ms/step - loss: 0.1209 - dice_coef: 0.5818 - val_loss: 0.4291 - val_dice_coef: 0.0317
# Epoch 48/1000
# 4/4 [==============================] - 2s 504ms/step - loss: 0.1345 - dice_coef: 0.5783 - val_loss: 0.4260 - val_dice_coef: 0.0358
# Epoch 49/1000
# 4/4 [==============================] - 2s 500ms/step - loss: 0.1197 - dice_coef: 0.5823 - val_loss: 0.4188 - val_dice_coef: 0.0400
# Epoch 50/1000
# 4/4 [==============================] - 2s 504ms/step - loss: 0.1274 - dice_coef: 0.5830 - val_loss: 0.4028 - val_dice_coef: 0.0509
# Epoch 51/1000
# 4/4 [==============================] - 2s 503ms/step - loss: 0.1171 - dice_coef: 0.5974 - val_loss: 0.4083 - val_dice_coef: 0.0464
# Epoch 52/1000
# 4/4 [==============================] - 2s 502ms/step - loss: 0.1144 - dice_coef: 0.5986 - val_loss: 0.3871 - val_dice_coef: 0.0568
# Epoch 53/1000
# 4/4 [==============================] - 2s 502ms/step - loss: 0.1112 - dice_coef: 0.5974 - val_loss: 0.3508 - val_dice_coef: 0.0849
# Epoch 54/1000
# 4/4 [==============================] - 2s 500ms/step - loss: 0.1154 - dice_coef: 0.5935 - val_loss: 0.3788 - val_dice_coef: 0.0657
# Epoch 55/1000
# 4/4 [==============================] - 2s 503ms/step - loss: 0.1187 - dice_coef: 0.5953 - val_loss: 0.3579 - val_dice_coef: 0.0855
# Epoch 56/1000
# 4/4 [==============================] - 2s 504ms/step - loss: 0.1259 - dice_coef: 0.5988 - val_loss: 0.3391 - val_dice_coef: 0.1066
# Epoch 57/1000
# 4/4 [==============================] - 2s 504ms/step - loss: 0.1199 - dice_coef: 0.5995 - val_loss: 0.3223 - val_dice_coef: 0.1277
# Epoch 58/1000
# 4/4 [==============================] - 2s 510ms/step - loss: 0.1174 - dice_coef: 0.5998 - val_loss: 0.3372 - val_dice_coef: 0.1192
# Epoch 59/1000
# 4/4 [==============================] - 2s 504ms/step - loss: 0.1142 - dice_coef: 0.6094 - val_loss: 0.3465 - val_dice_coef: 0.1157
# Epoch 60/1000
# 4/4 [==============================] - 2s 506ms/step - loss: 0.1176 - dice_coef: 0.5983 - val_loss: 0.3172 - val_dice_coef: 0.1434
# Epoch 61/1000
# 4/4 [==============================] - 2s 503ms/step - loss: 0.1161 - dice_coef: 0.6065 - val_loss: 0.3284 - val_dice_coef: 0.1360
# Epoch 62/1000
# 4/4 [==============================] - 2s 504ms/step - loss: 0.1139 - dice_coef: 0.6197 - val_loss: 0.3402 - val_dice_coef: 0.1280
# Epoch 63/1000
# 4/4 [==============================] - 2s 505ms/step - loss: 0.1202 - dice_coef: 0.6141 - val_loss: 0.3182 - val_dice_coef: 0.1490
# Epoch 64/1000
# 4/4 [==============================] - 2s 505ms/step - loss: 0.1142 - dice_coef: 0.6086 - val_loss: 0.2917 - val_dice_coef: 0.1794
# Epoch 65/1000
# 4/4 [==============================] - 2s 504ms/step - loss: 0.1224 - dice_coef: 0.6131 - val_loss: 0.2731 - val_dice_coef: 0.2089
# Epoch 66/1000
# 4/4 [==============================] - 2s 504ms/step - loss: 0.1057 - dice_coef: 0.6237 - val_loss: 0.2479 - val_dice_coef: 0.2616
# Epoch 67/1000
# 4/4 [==============================] - 2s 505ms/step - loss: 0.1260 - dice_coef: 0.6007 - val_loss: 0.2871 - val_dice_coef: 0.2123
# Epoch 68/1000
# 4/4 [==============================] - 2s 509ms/step - loss: 0.1176 - dice_coef: 0.6207 - val_loss: 0.3533 - val_dice_coef: 0.1709
# Epoch 69/1000
# 4/4 [==============================] - 2s 509ms/step - loss: 0.1092 - dice_coef: 0.6093 - val_loss: 0.3657 - val_dice_coef: 0.1674
# Epoch 70/1000
# 4/4 [==============================] - 2s 507ms/step - loss: 0.1108 - dice_coef: 0.5976 - val_loss: 0.3569 - val_dice_coef: 0.1902
# Epoch 71/1000
# 4/4 [==============================] - 2s 510ms/step - loss: 0.1169 - dice_coef: 0.6164 - val_loss: 0.3506 - val_dice_coef: 0.1983
# Epoch 72/1000
# 4/4 [==============================] - 2s 509ms/step - loss: 0.1188 - dice_coef: 0.6147 - val_loss: 0.2985 - val_dice_coef: 0.2553
# Epoch 73/1000
# 4/4 [==============================] - 2s 510ms/step - loss: 0.1055 - dice_coef: 0.6201 - val_loss: 0.2713 - val_dice_coef: 0.2835
# Epoch 74/1000
# 4/4 [==============================] - 2s 507ms/step - loss: 0.1057 - dice_coef: 0.6178 - val_loss: 0.2612 - val_dice_coef: 0.2951
# Epoch 75/1000
# 4/4 [==============================] - 2s 508ms/step - loss: 0.1172 - dice_coef: 0.6122 - val_loss: 0.2610 - val_dice_coef: 0.2998
# Epoch 76/1000
# 4/4 [==============================] - 2s 511ms/step - loss: 0.1197 - dice_coef: 0.5957 - val_loss: 0.2278 - val_dice_coef: 0.3510
# Epoch 77/1000
# 4/4 [==============================] - 2s 510ms/step - loss: 0.1178 - dice_coef: 0.6226 - val_loss: 0.2042 - val_dice_coef: 0.3922
# Epoch 78/1000
# 4/4 [==============================] - 2s 508ms/step - loss: 0.1137 - dice_coef: 0.6145 - val_loss: 0.1939 - val_dice_coef: 0.3993
# Epoch 79/1000
# 4/4 [==============================] - 2s 515ms/step - loss: 0.1151 - dice_coef: 0.6163 - val_loss: 0.2176 - val_dice_coef: 0.3728
# Epoch 80/1000
# 4/4 [==============================] - 2s 508ms/step - loss: 0.1134 - dice_coef: 0.6124 - val_loss: 0.2102 - val_dice_coef: 0.4083
# Epoch 81/1000
# 4/4 [==============================] - 2s 511ms/step - loss: 0.1121 - dice_coef: 0.6222 - val_loss: 0.1865 - val_dice_coef: 0.4498
# Epoch 82/1000
# 4/4 [==============================] - 2s 511ms/step - loss: 0.1166 - dice_coef: 0.6139 - val_loss: 0.1789 - val_dice_coef: 0.4455
# Epoch 83/1000
# 4/4 [==============================] - 2s 508ms/step - loss: 0.1151 - dice_coef: 0.6165 - val_loss: 0.1605 - val_dice_coef: 0.4795
# Epoch 84/1000
# 4/4 [==============================] - 2s 513ms/step - loss: 0.1120 - dice_coef: 0.6315 - val_loss: 0.1607 - val_dice_coef: 0.4698
# Epoch 85/1000
# 4/4 [==============================] - 2s 510ms/step - loss: 0.1098 - dice_coef: 0.6228 - val_loss: 0.1619 - val_dice_coef: 0.4574
# Epoch 86/1000
# 4/4 [==============================] - 2s 510ms/step - loss: 0.1023 - dice_coef: 0.6332 - val_loss: 0.1639 - val_dice_coef: 0.4752
# Epoch 87/1000
# 4/4 [==============================] - 2s 509ms/step - loss: 0.1114 - dice_coef: 0.6302 - val_loss: 0.1699 - val_dice_coef: 0.4682
# Epoch 88/1000
# 4/4 [==============================] - 2s 509ms/step - loss: 0.1013 - dice_coef: 0.6252 - val_loss: 0.1658 - val_dice_coef: 0.4822
# Epoch 89/1000
# 4/4 [==============================] - 2s 511ms/step - loss: 0.1135 - dice_coef: 0.6257 - val_loss: 0.1611 - val_dice_coef: 0.4946
# Epoch 90/1000
# 4/4 [==============================] - 2s 510ms/step - loss: 0.1081 - dice_coef: 0.6321 - val_loss: 0.1507 - val_dice_coef: 0.5168
# Epoch 91/1000
# 4/4 [==============================] - 2s 510ms/step - loss: 0.0993 - dice_coef: 0.6333 - val_loss: 0.1482 - val_dice_coef: 0.5349
# Epoch 92/1000
# 4/4 [==============================] - 2s 512ms/step - loss: 0.1115 - dice_coef: 0.6341 - val_loss: 0.1446 - val_dice_coef: 0.5431
# Epoch 93/1000
# 4/4 [==============================] - 2s 514ms/step - loss: 0.1091 - dice_coef: 0.6302 - val_loss: 0.1373 - val_dice_coef: 0.5630
# Epoch 94/1000
# 4/4 [==============================] - 2s 511ms/step - loss: 0.1114 - dice_coef: 0.6366 - val_loss: 0.1333 - val_dice_coef: 0.5714
# Epoch 95/1000
# 4/4 [==============================] - 2s 511ms/step - loss: 0.1058 - dice_coef: 0.6313 - val_loss: 0.1418 - val_dice_coef: 0.5273
# Epoch 96/1000
# 4/4 [==============================] - 2s 515ms/step - loss: 0.1105 - dice_coef: 0.6309 - val_loss: 0.1343 - val_dice_coef: 0.5652
# Epoch 97/1000
# 4/4 [==============================] - 2s 513ms/step - loss: 0.1113 - dice_coef: 0.6259 - val_loss: 0.1382 - val_dice_coef: 0.5433
# Epoch 98/1000
# 4/4 [==============================] - 2s 514ms/step - loss: 0.1103 - dice_coef: 0.6319 - val_loss: 0.1292 - val_dice_coef: 0.5705
# Epoch 99/1000
# 4/4 [==============================] - 2s 514ms/step - loss: 0.1123 - dice_coef: 0.6442 - val_loss: 0.1250 - val_dice_coef: 0.5729
# Epoch 100/1000
# 4/4 [==============================] - 2s 515ms/step - loss: 0.1130 - dice_coef: 0.6334 - val_loss: 0.1266 - val_dice_coef: 0.5656
# Epoch 101/1000
# 4/4 [==============================] - ETA: 0s - loss: 0.1052 - dice_coef: 0.6458
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-a1de10df11dc> in <module>()
#       2                  validation_data = val_gen,
#       3                  epochs=1000,
# ----> 4                  callbacks = [weight_saver, earlystop])
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1223               use_multiprocessing=use_multiprocessing,
#    1224               return_dict=True,
# -> 1225               _use_cached_eval_dataset=True)
#    1226           val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1227           epoch_logs.update(val_logs)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1481       self._test_counter.assign(0)
#    1482       callbacks.on_test_begin()
# -> 1483       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1484         self.reset_metrics()
#    1485         with data_handler.catch_stop_iteration():
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1202           break
#    1203         if self._adapter.should_recreate_iterator():
# -> 1204           data_iterator = iter(self._dataset)
#    1205         yield epoch, data_iterator
#    1206         self._adapter.on_epoch_end()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     694       if (components is not None or element_spec is not None):
#     695         raise ValueError(error_message)
# --> 696       self._create_iterator(dataset)
#     697
#     698   def _create_iterator(self, dataset):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     698   def _create_iterator(self, dataset):
#     699     # pylint: disable=protected-access
# --> 700     dataset = dataset._apply_options()
#     701
#     702     # Store dataset reference to ensure that dataset is alive when this iterator
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in _apply_options(self)
#     461       dataset = _OptimizeDataset(dataset, graph_rewrites.enabled,
#     462                                  graph_rewrites.disabled,
# --> 463                                  graph_rewrites.default, graph_rewrite_configs)
#     464
#     465     # (4) Apply stats aggregator options
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, optimizations_enabled, optimizations_disabled, optimizations_default, optimization_configs)
#    4894         self._optimizations_default,
#    4895         optimization_configs=optimization_configs,
# -> 4896         **self._flat_structure)
#    4897
#    4898     super(_OptimizeDataset, self).__init__(input_dataset, variant_tensor)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in optimize_dataset_v2(input_dataset, optimizations_enabled, optimizations_disabled, optimizations_default, output_types, output_shapes, optimization_configs, name)
#    4172         optimizations_disabled, optimizations_default, "output_types",
#    4173         output_types, "output_shapes", output_shapes, "optimization_configs",
# -> 4174         optimization_configs)
#    4175       return _result
#    4176     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Evaluate

# %%
history = logs.history
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('loss')
plt.show()
plt.plot(history['dice_coef'])
plt.plot(history['val_dice_coef'])
plt.title('Dice')
plt.show()

# %%
model_final = models.load_model('seg.h5', compile=False)

# %%
# Sample 1 batch
batch_idx = np.random.randint(len(val_gen))
print(batch_idx)
data = val_gen[batch_idx]
imgs, mask = data # (bs, 512, 512, 3), (bs, 512, 512, 1)
mask_pred = model_final.predict(imgs)

# show inputs
img_idx = np.random.randint(len(imgs)) # sample 1 image from batch
plt.figure(figsize=(20, 5))
plt.subplot(1,3,1)
plt.imshow(imgs[img_idx])

# show ground truth & model prediction
plt.subplot(1, 3, 2)
plt.imshow(mask[img_idx, :, :, 0], cmap='gray_r')
plt.subplot(1, 3, 3)
plt.imshow(mask_pred[img_idx, :, :, 0], cmap='gray_r')
plt.show()
# plt.imshow(mask_pred[img_idx, :, :, 0], cmap='gray')
# Out:
# 0

# %%
# Displayed with different threshold
mask_pred_raw = mask_pred[img_idx, :, :, 0]
mask_pred_raw
# Out:
# array([[0.02452922, 0.01490205, 0.01142817, ..., 0.00938654, 0.01262447,
#         0.0194975 ],
#        [0.01160561, 0.00547277, 0.0041548 , ..., 0.00238651, 0.00406553,
#         0.01010927],
#        [0.00960109, 0.00376551, 0.00312843, ..., 0.00160357, 0.00295767,
#         0.00905978],
#        ...,
#        [0.01139885, 0.00481887, 0.00487674, ..., 0.00269837, 0.00438118,
#         0.01191861],
#        [0.0126349 , 0.00550145, 0.00433083, ..., 0.00260394, 0.00415595,
#         0.0123999 ],
#        [0.02075095, 0.0106318 , 0.00832134, ..., 0.00559906, 0.00787085,
#         0.01690985]], dtype=float32)

# %%
plt.imshow(mask[img_idx, :, :, 0], cmap='gray_r')
plt.title('Ground Truth')
plt.show()

plt.figure(figsize=(20, 10))
for i in range(1, 10):
    plt.subplot(2, 5, i)
    threshold = i * 0.1
    mask_threshold = mask_pred_raw.copy()
    mask_threshold[mask_threshold <= threshold] = 0.
    mask_threshold[mask_threshold > threshold] = 1.
    plt.imshow(mask_threshold, cmap='gray_r')
    plt.title(f'threshold: {threshold:.1f}')
plt.show()

# %%
# make prediction
threshold = 0.5
outputs = []
for i in range(len(test_gen)):
    x_test = test_gen[i]
    y_preds = model_final.predict(x_test)
    y_preds[y_preds <= threshold] = 0
    y_preds[y_preds > threshold] = 1
    for y_pred in y_preds:
        dots = np.where(y_pred.flatten() == 1)[0]
        run_lengths = []
        prev = -2
        for b in dots:
            if (b > prev +1):
                run_lengths.extend((b+1,0))
            run_lengths[-1] += 1
            prev = b
        output = ' '.join([str(r) for r in run_lengths])
        outputs.append(output)

# %%
df = pd.DataFrame(columns=['Id', 'Predicted'])
df['Id'] = [str(i) for i in range(20)]
df['Predicted'] = outputs
df.to_csv('submission.csv', index=None)
df
# Out:
#     Id                                          Predicted
# 0    0  15613 6 16115 34 16614 3 16618 11 16631 1 1664...
# 1    1  14608 4 15121 4 16130 2 16641 5 17130 5 17154 ...
# 2    2  14629 2 15664 6 16177 4 18127 1 18639 1 19150 ...
# 3    3  14584 3 15096 4 15609 4 15666 1 16122 3 16635 ...
# 4    4  16676 2 17188 3 19234 2 19746 2 20257 3 20768 ...
# 5    5  17155 2 17667 2 18213 3 18725 6 19239 6 19753 ...
# 6    6  17123 8 17160 9 17635 11 17674 8 18150 10 1819...
# 7    7  16617 3 17129 4 17642 5 18155 5 18193 1 18669 ...
# 8    8  14101 4 14616 1 15638 2 16114 3 16131 14 16147...
# 9    9  17665 1 18138 2 18177 2 18650 4 18690 1 19162 ...
# 10  10  16080 1 17623 8 18127 12 18206 6 18635 13 1872...
# 11  11  14569 1 15081 1 15593 1 16104 2 16115 33 16616...
# 12  12  17160 4 17181 1 17666 4 17672 5 17693 3 18145 ...
# 13  13  13595 1 14106 3 14618 3 15131 3 15644 2 16156 ...
# 14  14  18641 2 19152 3 19166 2 19206 1 19663 3 19678 ...
# 15  15  16171 3 16653 1 17166 2 17679 2 18192 2 18706 ...
# 16  16  22707 3 23222 2 23735 2 24248 2 24760 3 25273 ...
# 17  17  17154 2 17161 8 17665 1 17679 2 17696 1 18175 ...
# 18  18  16643 2 17154 4 17667 3 18179 4 18692 3 18733 ...
# 19  19  18673 1 20169 6 20276 4 20680 10 20790 4 21193...

# %%
aaa = np.zeros(shape=(128, 128, 1))

# %%
bbb = K.flatten(aaa)

# %%
bbb
# Out:
# <tf.Tensor: shape=(16384,), dtype=float64, numpy=array([0., 0., 0., ..., 0., 0., 0.])>
